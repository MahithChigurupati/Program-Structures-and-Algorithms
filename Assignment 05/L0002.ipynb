# %% [markdown]
# ## 2. Add Two Numbers
# ## https://leetcode.com/problems/add-two-numbers/
# ## Jagadeesh Vasudevamurthy

# %% [markdown]
# # Write code below

# %%
############################################################
# L0002.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2022
###########################################################

############################################################
# https://leetcode.com/problems/add-two-numbers/
###########################################################

class Solution:
    #NOTHING CAN BE CHANGED BELOW
    def addTwoNumbers(self, l1: 'ListNode', l2: 'ListNode')->'ListNode':
        show = False
        assert_answers = True
        ans = [None] #List of size 1
        h = L0002(l1,l2,ans,assert_answers,show)
        return ans[0]

class L0002:
    def __init__(self, l1: 'ListNode', l2: 'ListNode', ans:'listNode of size 1', assert_answers:'bool',show:'bool') -> None:
        #NOTHING CAN BE CHANGED BELOW
        self._a = Slist()
        self._a._first = l1
        self._b = Slist()
        self._b._first = l2
        self._ans = ans
        self._alg()
        
    def _alg(self):
        c = self._a + self._b
        self._ans[0] = c._first


class Slist():
    def __init__(self):
        #NOTHING CAN BE CHANGED HERE
        self._first = None
        self._last = None

    #############################
    # WRITE CODE BELOW
    #############################
    
    def __add__(self, b):
        a = self._first
        b = b._first
        carry = 0
        c = Slist()
        c._first = c._last = ListNode()
        currentNode = c._first
        while(a != None or b != None or carry!=0):
            if(a != None):
                value1 = a.val
            else:
                value1 = 0
            
            if(b != None):
                value2 = b.val
            else:
                value2 = 0
                
            sum_total = value1 + value2 + carry
            rem = sum_total % 10
            currentNode.next = ListNode(rem)
            carry = sum_total//10
            
            if a != None:
                a = a.next 
            if b != None:
                b = b.next

            currentNode = currentNode.next
        c._first = c._first.next
        return c

# %% [markdown]
# ##  NO test bench. Use Slist object to learn

# %% [markdown]
# ![image.png](attachment:image.png)
