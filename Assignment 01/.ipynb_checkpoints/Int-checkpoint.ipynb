# %% [markdown]
# # CSYE 6205: Program Structures and Algorithms

# %% [markdown]
# Assignment I
#
# Requirement: Implement class Int

# %% [markdown]
# Developer: SaiMahith Chigurupati
#
# NUID: 002700539
#
# Email: chigurupati.sa@northeastern.edu

# %% [markdown]
# # Class Int

# %%
## imports required for Int.py

import sys
import os
print(sys.version)
# Out:
# 3.9.13 (main, Aug 25 2022, 18:29:29)
# [Clang 12.0.0 ]

# %%
############################################################
# Int.py 
# Implements Int object
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################


###########################################################
#  class  Int
###########################################################   
class Int():
    def __init__(self,n:'int' = 0):  
        #ONLY DATA STRUCTURE ALLOWED
        #self._positive
        #self._a
        self._positive = True
        if(n < 0):
            self._positive = False
        self._a = self.build(n)

    #############################
    # WRITE All public functions BELOW
    # YOU CAN HAVE ANY NUMBER OF PRIVATE FUNCTIONS YOU WANT
    #############################

    def build(self, n: 'int') -> 'list of int':
        if(n < 0):
            n = -n
        l = []
        if(n < 10):
            l.append(n)
        else:
            while(n != 0):
                l.append(n % 10)
                n = n // 10
        self._reverse(l)
        return l

    def int(self) -> 'integer':
        v = 0
        for e in self._a:
            v = v * 10 + e
        if(v == 0 or self._positive):
            return v
        return -v

    ##############################################################
    # WRITE All private functions BELOW
    # YOU CAN HAVE ANY NUMBER OF PRIVATE FUNCTIONS YOU WANT
    ##############################################################

    def _reverse(self, l: 'list of int') -> 'None':
        i = 0
        j = len(l) - 1
        while(i < j):
            t = l[i]
            l[i] = l[j]
            l[j] = t
            i = i + 1
            j = j - 1

    def __str__(self) -> 'String':
        n = self.int()
        sign = "-"
        if(self._positive):
            sign = "+"
        
        s = str(n) + " " + sign + "["
        d = len(self)
        for i in range(d):
            x = self[i]
            s = s + str(x)
            if(i < d - 1):
                s = s + ", "
        s = s + "]"
        return s

    def __len__(self) -> 'int':
        return len(self._a)
    
    def __getitem__(self, pos) -> 'int':
        n = len(self)
        assert(pos >= 0 and pos < n)
        return self._a[pos]

    def __setitem__(self, pos, v) -> 'None':
        n = len(self)
        assert(pos >= 0 and pos < n)
        self._a[pos] = v

    def __add__(self, b: 'Int') -> 'Int':
        va = self.int()
        vb = b.int()
        vc = va + vb
        c = Int(vc)
        return c

    def __sub__(self, b: 'Int') -> 'Int':
        va = self.int()
        vb = b.int()
        vc = va - vb
        c = Int(vc)
        return c
    
    def __lt__(self, b: 'Int') -> 'bool':
        va = self.int()
        vb = b.int()
        return (va < vb)

    def __gt__(self, b: 'Int') -> 'bool':
        va = self.int()
        vb = b.int()
        return (va > vb)

    def __eq__(self, b: 'Int') -> 'bool':
        va = self.int()
        vb = b.int()
        return (va == vb)
    
    def __ne__(self, b: 'Int') -> 'bool':
        va = self.int()
        vb = b.int()
        return (va != vb)

# %%
import sys 
from typing import List

class Inttest():
    def __init__(self):
        pass
    
    def data_structure(self):
        print("------------Testing data_structure-----------------")
        a = Int()
        print(a)
        a = Int(100)
        print(a)
        a = Int(-100)
        print(a)
        n = -10098765456786542342222
        a = Int(n)
        print(a)
        ans = [1,0,0,9,8,7,6,5,4,5,6,7,8,6,5,4,2,3,4,2,2,2,2]  
        d = len(a)
        d1 = len(ans) 
        if (d != d1):
            print("Number of digits is ", d1," Your answer is", d)
        assert(d == d1)
        print("--------------- data_structure Passed --------------- ")

    def access(self):
        print("------------Testing access -----------------")
        n = -10098765456786542342222
        a = Int(n)
        print(a)
        ans = [1,0,0,9,8,7,6,5,4,5,6,7,8,6,5,4,2,3,4,2,2,2,2]  
        d = len(a)
        d1 = len(ans) 
        if (d != d1):
            print("Number of digits is ", d1," Your answer is", d)
        assert(d == d1)
        for i in range(d):
            e = a[i]
            e1 = ans[i]
            if (e != e1):
                print("a[",i,"] = ",e1, "But your answer is",e)
            assert(e == e1)
        a[0] = 5 ;
        print(a)
        n = a.int()
        n1 = -50098765456786542342222
        if (n != n1):
            print("Correct ans=",n1,"But your answer is",n)
        assert(n == n1)
        print("--------------- access Passed --------------- ")

    def arithmetic(self):
        print("------------Testing arithmetic-----------------")
        q = [0, 5, -91, 1086, 1235657786899879757575175157511571, -12356577868998797575789107815]
        s = len(q)
        print("---------------  Testing +  --------------- ")
        for i in range(s):
            m = q[i]
            a = Int(m)
            print("a = ",end="")
            print(a)
            n = q[s-1-i]
            b = Int(n)
            print("b = ",end="")
            print(b)
       
            mn = m + n
            c = a + b 
            print("c = ",end="")
            print(c)
            vc = c.int()
            if (vc != mn):
                print("Expected value is: ", mn, "But your answer is", vc) ;
                assert(0)

        print("--------------- + Passed --------------- ")

        print("---------------  Testing -  --------------- ")
        for i in range(s):
            m = q[i]
            a = Int(m)
            print("a = ",end="")
            print(a)
            n = q[s-1-i]
            b = Int(n)
            print("b = ",end="")
            print(b)
       
            mn = m - n
            c = a - b 
            print("c = ",end="")
            print(c)
            vc = c.int()
            if (vc != mn):
                print("Expected value is: ", mn, "But your answer is", vc) 
                assert(0)

        print("--------------- - Passed --------------- ")

       
        print("--------------- arithmetic Passed --------------- ")

    def relational(self):
        print("-------------Testing arithmetic-----------------")
        q1 = [0, 3, 2, -3, -2, 5, 5, -5,-5, -91, 1086, 1235657786899879757575175157511571, -12356577868998797575789107815,-12356577868998797575789107815]
        q2 = [-1,2, 3,  2,  3, 5, -5, 5, -5, 91, 1085, 1235657786899879757575175157511570, -12356577868998797575789207815,-12356577868998797575789107815]
        s = len(q1)
        print("---------------  Testing <  --------------- ")
        for i in range(s):
            m = q1[i]
            a = Int(m)
            print("a = ",end="")
            print(a)
            n = q2[i]
            b = Int(n)
            print("b = ",end="")
            print(b)    
            mn = m < n
            c = (a < b) 
            assert(c == 0 or c == 1)
            print("is a < b",c)     
            if (c != mn):
                print("Expected value is: ", mn, "But your answer is", c) 
                assert(0)
        print("--------------- < Passed --------------- ")

        print("---------------  Testing >  --------------- ")
        for i in range(s):
            m = q1[i]
            a = Int(m)
            print("a = ",end="")
            print(a)
            n = q2[i]
            b = Int(n)
            print("b = ",end="")
            print(b)
            mn = (m > n)
            c = (a > b)
            assert(c == 0 or c == 1)
            print("is a > b",c)          
            if (c != mn):
                print("Expected value is: ", mn, "But your answer is", c) 
                assert(0)
        print("--------------- < Passed --------------- ")

        print("---------------  Testing ==  --------------- ")
        for i in range(s):
            m = q1[i]
            a = Int(m)
            print("a = ",end="")
            print(a)
            n = q2[i]
            b = Int(n)
            print("b = ",end="")
            print(b)
            mn = (m == n)
            c = (a == b)
            assert(c == 0 or c == 1)
            print("is a == b",c)          
            if (c != mn):
                print("Expected value is: ", mn, "But your answer is", c) 
                assert(0)
        print("--------------- == Passed --------------- ")

        print("---------------  Testing !=  --------------- ")
        for i in range(s):
            m = q1[i]
            a = Int(m)
            print("a = ",end="")
            print(a)
            n = q2[i]
            b = Int(n)
            print("b = ",end="")
            print(b)
            mn = (m != n)
            c = (a != b)
            assert(c == 0 or c == 1)
            print("is a != b",c)          
            if (c != mn):
                print("Expected value is: ", mn, "But your answer is", c) 
                assert(0)
        print("--------------- != Passed --------------- ")


        
# MAIN
def main():
    print("Basic Int test starts")
    print(sys.version)
    t = Inttest()
#     t.data_structure()
#     t.access() 
    t.arithmetic() 
#     t.relational() 
    print("Basic Int test Ends")

# %%
if (__name__  == '__main__'):
    main()
# Out:
# Basic Int test starts
# 3.9.13 (main, Aug 25 2022, 18:29:29)
# [Clang 12.0.0 ]
# ------------Testing arithmetic-----------------
# ---------------  Testing +  ---------------
# a = 0 +[0]
# b = -12356577868998797575789107815 -[1,2,3,5,6,5,7,7,8,6,8,9,9,8,7,9,7,5,7,5,7,8,9,1,0,7,8,1,5]
# c = -12356577868998797575789107815
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 2
#       1 if (__name__  == '__main__'):
# ----> 2     main()
#
# Cell In[84], line 196, in main()
#     193     t = Inttest()
#     194 #     t.data_structure()
#     195 #     t.access()
# --> 196     t.arithmetic()
#     197 #     t.relational()
#     198     print("Basic Int test Ends")
#
# Cell In[84], line 73, in Inttest.arithmetic(self)
#      71 print("c = ",end="")
#      72 print(c)
# ---> 73 vc = c.int()
#      74 if (vc != mn):
#      75     print("Expected value is: ", mn, "But your answer is", vc) ;
#
# AttributeError: 'int' object has no attribute 'int'
